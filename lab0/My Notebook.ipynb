# %%
# Import several libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('/home/terrapin/datascience-fall14/data/Capital-Bike-Share-June-30-2014.csv', parse_dates = ['Start date', 'End date'])

# %%
duration = pd.DataFrame({'duration_in_seconds' : [(int(x.split(" ")[0][:-1])*3600 + int(x.split(" ")[1][:-1])*60 + int(x.split(" ")[1][:-1])) for x in data['Duration']]})
duration.plot()
